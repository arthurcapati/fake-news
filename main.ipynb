# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from src.train import train_sklearn_models, grid_search
from src.load_data import DataProcessor
import mlflow
import numpy as np

# %% [markdown]
# Treinamento de Modelos

# %%
models = [MultinomialNB, SVC, RandomForestClassifier, DecisionTreeClassifier]
params = [
    {"alpha": 0.1, "random_state": 22},
    {"C": 1, "probability": True, "random_state": 22},
    {"n_estimators": 10, "max_depth": 2,"random_state": 22},
    {"max_depth": 2, "random_state": 22},
]

# %%
mlflow.set_tracking_uri("http://127.0.0.1:8080/")
mlflow.set_experiment("fake-news")
for model, param in zip(models, params):
    with mlflow.start_run() as run:
        mlflow.set_tag('mlflow.runName', f'{model.__name__}')
        train_sklearn_models(model, param)
        mlflow.end_run()

# %% [markdown]
# Otimização dos Modelos

# %%
models = [MultinomialNB, SVC, RandomForestClassifier, DecisionTreeClassifier]
params_grid = [
    {"alpha": np.linspace(0.1, 1, 15)},
    {"C": np.linspace(0.1, 5, 12)},
    {"n_estimators": np.array(range(2, 562, 20)), "max_depth": np.array(range(2, 6))},
    {"max_depth": np.array(range(2, 40, 2))},
]
params = [
    {"random_state": 22},
    {"probability": True, "random_state": 22},
    {"random_state": 22},
    {"random_state": 22},
]

# %%
mlflow.set_tracking_uri("http://127.0.0.1:8080/")
mlflow.set_experiment("fake-news-gridsearch")
for model, param_grid, param in zip(models, params_grid, params):
    with mlflow.start_run() as run:
        mlflow.set_tag('mlflow.runName', f'GRIDSPACE: {model.__name__}')
        grid_search(model, param, param_grid)
        mlflow.end_run()
# Out:
# 2025/02/27 21:03:34 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# f:\Tuga\Projetos\Programacao\python\Tutoriais\FakeNews\venv\Lib\site-packages\mlflow\data\dataset_source_registry.py:149: UserWarning: Failed to determine whether UCVolumeDatasetSource can resolve source information for 'data/fake_or_real_news.csv'. Exception:
#   return _dataset_source_registry.resolve(
# f:\Tuga\Projetos\Programacao\python\Tutoriais\FakeNews\venv\Lib\site-packages\mlflow\data\dataset_source_registry.py:149: UserWarning: The specified dataset source can be interpreted in multiple ways: LocalArtifactDatasetSource, LocalArtifactDatasetSource. MLflow will assume that this is a LocalArtifactDatasetSource source.
#   return _dataset_source_registry.resolve(
# ...

# %% [markdown]
# Explanability

# %%
mlflow.set_tracking_uri("http://127.0.0.1:8080/")
model_name = "fake-news"
model_version = "latest"

# Load the model from the Model Registry
model_uri = f"models:/{model_name}/{model_version}"
model = mlflow.sklearn.load_model(model_uri)
# Out:
# f:\Tuga\Projetos\Programacao\python\Tutoriais\FakeNews\venv\Lib\site-packages\mlflow\store\artifact\utils\models.py:31: FutureWarning: ``mlflow.tracking.client.MlflowClient.get_latest_versions`` is deprecated since 2.9.0. Model registry stages will be removed in a future major release. To learn more about the deprecation of model registry stages, see our migration guide here: https://mlflow.org/docs/latest/model-registry.html#migrating-from-stages
#   latest = client.get_latest_versions(name, None if stage is None else [stage])
# ...

# %%
dataprocessor = DataProcessor()
title1 = "Trump is an alien from other dimension"
pred1 = model.predict(dataprocessor.transform_features([title1]))
print(f"Titulo: {title1} - Prediction: {pred1}")

title2 = "Republicans press House leadership for help as they face pressure over DOGE cuts at home"
pred2 = model.predict(dataprocessor.transform_features([title2]))
print(f"Titulo: {title2} - Prediction: {pred2}")
# Out:
# f:\Tuga\Projetos\Programacao\python\Tutoriais\FakeNews\venv\Lib\site-packages\mlflow\data\dataset_source_registry.py:149: UserWarning: Failed to determine whether UCVolumeDatasetSource can resolve source information for 'data/fake_or_real_news.csv'. Exception:
#   return _dataset_source_registry.resolve(
# f:\Tuga\Projetos\Programacao\python\Tutoriais\FakeNews\venv\Lib\site-packages\mlflow\data\dataset_source_registry.py:149: UserWarning: The specified dataset source can be interpreted in multiple ways: LocalArtifactDatasetSource, LocalArtifactDatasetSource. MLflow will assume that this is a LocalArtifactDatasetSource source.
#   return _dataset_source_registry.resolve(
# Titulo: Trump is an alien from other dimension - Prediccion: [0]
# Titulo: Republicans press House leadership for help as they face pressure over DOGE cuts at home - Prediccion: [1]
# ...

# %%
import shap

def explain(title):
    # Criar um modelo wrapper
    def model_predict(X):
        return model.predict(X)
    
    cv = DataProcessor().vectorizer
    background = np.zeros((1, cv.transform([""]).shape[1]))

    explainer = shap.KernelExplainer(model_predict, background)
    return explainer.shap_values(cv.transform([title]))

cv = DataProcessor().vectorizer
feature_names = cv.get_feature_names_out()  # Obtém as palavras do CountVectorizer
# Obtém os nomes das classes do modelo (Fake ou Real)
class_names = ["Fake", "Real"]  # Altere conforme necessário para sua base de dados


title = title1
shap_values = explain(title)
shap.summary_plot(shap_values, cv.transform([title]), feature_names=feature_names, class_names=class_names, max_display=len(title.split(" ")))


title = title2
shap_values = explain(title)
shap.summary_plot(shap_values, cv.transform([title]), feature_names=feature_names, class_names=class_names, max_display=len(title.split(" ")))
# Out:
# f:\Tuga\Projetos\Programacao\python\Tutoriais\FakeNews\venv\Lib\site-packages\mlflow\data\dataset_source_registry.py:149: UserWarning: Failed to determine whether UCVolumeDatasetSource can resolve source information for 'data/fake_or_real_news.csv'. Exception:
#   return _dataset_source_registry.resolve(
# f:\Tuga\Projetos\Programacao\python\Tutoriais\FakeNews\venv\Lib\site-packages\mlflow\data\dataset_source_registry.py:149: UserWarning: The specified dataset source can be interpreted in multiple ways: LocalArtifactDatasetSource, LocalArtifactDatasetSource. MLflow will assume that this is a LocalArtifactDatasetSource source.
#   return _dataset_source_registry.resolve(
# f:\Tuga\Projetos\Programacao\python\Tutoriais\FakeNews\venv\Lib\site-packages\mlflow\data\dataset_source_registry.py:149: UserWarning: Failed to determine whether UCVolumeDatasetSource can resolve source information for 'data/fake_or_real_news.csv'. Exception:
#   return _dataset_source_registry.resolve(
# ...

# %%
shap.plots.text(shap_values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 shap.plots.text(shap_values)
#
# File f:\Tuga\Projetos\Programacao\python\Tutoriais\FakeNews\venv\Lib\site-packages\shap\plots\_text.py:81, in text(shap_values, num_starting_labels, grouping_threshold, separator, xmin, xmax, cmax, display)
#      78 uuid = ''.join(random.choices(string.ascii_lowercase, k=20))
#      80 # loop when we get multi-row inputs
# ---> 81 if len(shap_values.shape) == 2 and (shap_values.output_names is None or isinstance(shap_values.output_names, str)):
#      82     xmin = 0
#      83     xmax = 0
#
# AttributeError: 'numpy.ndarray' object has no attribute 'output_names'
